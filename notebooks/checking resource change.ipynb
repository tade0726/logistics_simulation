# %%
import sys

sys.path.extend(['..'])

from src.db import *
from config import *

import pandas as pd
import numpy as np

# %%
table = load_from_mysql('i_resource_limit')
# Out:
# 2017-08-25 09:30:08,136 - simulation - INFO - Reading Redis i_resource_limit

# %%
table.loc[table.resource_id.str.contains('r'), 'resource_limit'] = 1

# %%
table.loc[table.resource_id.str.contains('r')]
# Out:
#      resource_id resource_name  resource_limit  capacity_per_resource  \
# 96      man_r1_1         r1人力1             1.0                    1.0
# 97      man_r1_2         r1人力2             1.0                    1.0
# 98      man_r1_3         r1人力3             1.0                    1.0
# 99      man_r1_4         r1人力4             1.0                    1.0
# 100     man_r2_1         r2人力1             1.0                    1.0
# 101     man_r2_2         r2人力2             1.0                    1.0
# 102     man_r2_3         r2人力3             1.0                    1.0
# 103     man_r2_4         r2人力4             1.0                    1.0
# 104     man_r3_1         r3人力1             1.0                    1.0
# 105    man_r3_10        r3人力10             1.0                    1.0
# 106     man_r3_2         r3人力2             1.0                    1.0
# 107     man_r3_3         r3人力3             1.0                    1.0
# ...

# %%
# get all out data
