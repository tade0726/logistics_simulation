# %%
import sys
sys.path.append('..')
from src.db import *

# %%
table = load_from_mysql("i_equipment_io")
# Out:
# /opt/miniconda3/envs/simpy_py36/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 496")
#   result = self._query(query)

# %%
reload_dict = get_reload_setting()

# %%
reload_dict
# Out:
# {('010', 'reload', 'A'): ['c17_15',
#   'c17_17',
#   'c17_21',
#   'c17_19',
#   'c17_13',
#   'c16_3'],
#  ('010', 'reload', 'L'): ['c3_2', 'c3_1', 'c3_16', 'c3_14'],
#  ('010', 'small_sort', 'A'): ['c5_29', 'c6_29'],
#  ('020', 'reload', 'A'): ['c14_5', 'c16_3', 'c14_3'],
#  ('020', 'reload', 'L'): ['c3_2', 'c3_1', 'c3_16', 'c3_14'],
#  ('020', 'small_sort', 'A'): ['c5_59',
#   'c6_60',
#   'c5_60',
#   'c6_59',
#   'c5_58',
#   'c6_61',
#   'c5_61'],
#  ('021', 'reload', 'A'): ['c16_3'],
#  ('021', 'reload', 'L'): ['c2_45', 'c2_47'],
#  ('021', 'small_sort', 'A'): ['c7_8'],
#  ('021', 'small_sort', 'L'): ['c8_67'],
#  ('022', 'reload', 'A'): ['c17_11', 'c17_9', 'c16_3'],
#  ('022', 'reload', 'L'): ['c3_2', 'c3_1', 'c3_16', 'c3_14'],
#  ('022', 'small_sort', 'A'): ['c6_30', 'c5_30'],
#  ('023', 'reload', 'A'): ['c14_28', 'c14_26', 'c14_24', 'c13_1', 'c16_3'],
#  ('023', 'reload', 'L'): ['c3_2',
#   'c3_1',
#   'c3_8',
#   'c3_10',
#   'c3_12',
#   'c3_16',
#   'c3_14'],
# ...
