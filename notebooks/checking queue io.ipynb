# %%
import sys
sys.path.append("..")
import os
from os.path import join, splitext

import pandas as pd
from src.db import *

# %%
data = load_from_mysql('i_queue_io')
# Out:
# 2017-08-16 10:37:00,265 - django - INFO - Reading Redis i_queue_io

# %%
data[data.equipment_port_last == 'c9_1']
# Out:
#      equipment_port_last equipment_port_next equipment_type queue_id  \
# 1407                c9_1               c13_1              c   c9_c13
# 1408                c9_1              c13_10              c   c9_c13
# 1409                c9_1              c13_11              c   c9_c13
# 1410                c9_1              c13_12              c   c9_c13
# 1411                c9_1              c13_13              c   c9_c13
# 1412                c9_1              c13_14              c   c9_c13
# 1413                c9_1              c13_15              c   c9_c13
# 1414                c9_1              c13_16              c   c9_c13
# 1415                c9_1              c13_17              c   c9_c13
# 1416                c9_1              c13_18              c   c9_c13
# 1417                c9_1              c13_19              c   c9_c13
# 1418                c9_1               c13_2              c   c9_c13
# 1419                c9_1              c13_20              c   c9_c13
# ...
