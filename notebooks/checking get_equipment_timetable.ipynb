# %%
import sys
sys.path.append('..')

from config import *
from src.db.tools import *

# %%
table2 = get_equipment_timetable()
table2 = load_from_mysql('i_equipment_io')
# Out:
# 2017-08-17 12:05:42,670 - django - INFO - Reading Redis i_equipment_io
# 2017-08-17 12:05:44,567 - django - INFO - Reading Redis i_equipment_io

# %%
table1[table1.equipment_port == 'c12_99']
# Out:
#     equipment_port equipment_id  process_time allocate_rule  equipment_status  \
# 353         c12_99          c12          55.0          None                 1
#
#      start_time            end_time inserted_on modified_on
# 353         0.0 2017-07-25 21:30:00         NaT         NaT

# %%
table2[table2.equipment_port == 'c12_99']
# Out:
#       equipment_port equipment_id  process_time allocate_rule  \
# 335           c12_99          c12          55.0          None
# 1815          c12_99          c12          55.0          None
# 3295          c12_99          c12          55.0          None
# 4775          c12_99          c12          55.0          None
# 6255          c12_99          c12          55.0          None
# 7735          c12_99          c12          55.0          None
# 9215          c12_99          c12          55.0          None
# 10695         c12_99          c12          55.0          None
# 12175         c12_99          c12          55.0          None
# 13655         c12_99          c12          55.0          None
# 15135         c12_99          c12          55.0          None
#
#        equipment_status          start_time            end_time inserted_on  \
# 335                   1 2017-07-25 21:00:00 2017-07-25 21:30:00         NaT
# ...
